# %%
# !pip install -q transformers torch

from transformers import pipeline, set_seed

# Load Tiny GPT-2 (downloads in a few seconds)
generator = pipeline("text-generation", model="sshleifer/tiny-gpt2")

set_seed(42)

# Input prompt
prompt = "Artificial Intelligence will transform the future of"

# Generate text
outputs = generator(
    prompt,
    max_new_tokens=30,
    num_return_sequences=2,
    temperature=0.8,
    top_k=50,
    top_p=0.95,
    do_sample=True
)

# Print generated text
for i, out in enumerate(outputs, 1):
    print(f"--- Generated Text {i} ---")
    print(out["generated_text"])
    print()
# Out:
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# pytorch_model.bin:   0%|          | 0.00/2.51M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/29 [00:00<?, ?it/s]
# [transformers] GPT2LMHeadModel LOAD REPORT from: sshleifer/tiny-gpt2
# Key                                   | Status     |  |
# --------------------------------------+------------+--+-
# transformer.h.{0, 1}.attn.masked_bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0%|          | 0.00/2.51M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'top_k', 'max_new_tokens', 'do_sample', 'top_p', 'num_return_sequences', 'temperature'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# --- Generated Text 1 ---
# Artificial Intelligence will transform the future ofozyg incarcerMini Television Singapore Boone soy653 clearer Pocket ReduxaciousMini deflect Singapore courtyardoblshows Medic Television Medic membership courtyard clearer factors brutalityProsived membershipshows
#
# --- Generated Text 2 ---
# Artificial Intelligence will transform the future ofGy448 praying Redux Boone Bend representations factors brutality skillet Bend courtyard Bendived Tre TelevisionMostived skillet� Singapore skillet factorsobl 236Mini LateozygozygMini
